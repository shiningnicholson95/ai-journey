# %% [markdown]
# <a href="https://colab.research.google.com/github/shiningnicholson95/ai-journey/blob/main/Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn
print("Ready:", np.__version__, pd.__version__, sklearn.__version__)
# Out:
# Ready: 2.1.3 2.2.3 1.6.1
